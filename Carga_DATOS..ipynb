# %%
import json
import pandas as pd
import numpy as np

# %%
# %pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip3.13 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
Cambridge_data = pd.read_csv("listings.csv")
Cambridge_data
# Out:
#                        id                                       listing_url  \
# 0                    8521                 https://www.airbnb.com/rooms/8521
# 1                   11169                https://www.airbnb.com/rooms/11169
# 2                   19581                https://www.airbnb.com/rooms/19581
# 3                   27498                https://www.airbnb.com/rooms/27498
# 4                   79762                https://www.airbnb.com/rooms/79762
# ...                   ...                                               ...
# 1282  1313250609203710870  https://www.airbnb.com/rooms/1313250609203710870
# 1283  1313277221998634744  https://www.airbnb.com/rooms/1313277221998634744
# 1284  1313301960513049198  https://www.airbnb.com/rooms/1313301960513049198
# 1285  1314036192803424107  https://www.airbnb.com/rooms/1314036192803424107
# 1286  1316146649117544288  https://www.airbnb.com/rooms/1316146649117544288
#
#            scrape_id last_scraped           source  \
# ...

# %%
pd.options.display.max_rows = 10
print(Cambridge_data)
# Out:
#                        id                                       listing_url  \
# 0                    8521                 https://www.airbnb.com/rooms/8521
# 1                   11169                https://www.airbnb.com/rooms/11169
# 2                   19581                https://www.airbnb.com/rooms/19581
# 3                   27498                https://www.airbnb.com/rooms/27498
# 4                   79762                https://www.airbnb.com/rooms/79762
# ...                   ...                                               ...
# 1282  1313250609203710870  https://www.airbnb.com/rooms/1313250609203710870
# 1283  1313277221998634744  https://www.airbnb.com/rooms/1313277221998634744
# 1284  1313301960513049198  https://www.airbnb.com/rooms/1313301960513049198
# 1285  1314036192803424107  https://www.airbnb.com/rooms/1314036192803424107
# 1286  1316146649117544288  https://www.airbnb.com/rooms/1316146649117544288
#
#            scrape_id last_scraped           source  \
# ...

# %%
Cambridge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1287 entries, 0 to 1286
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            1287 non-null   int64
#  1   listing_url                                   1287 non-null   object
#  2   scrape_id                                     1287 non-null   int64
#  3   last_scraped                                  1287 non-null   object
#  4   source                                        1287 non-null   object
#  5   name                                          1287 non-null   object
#  6   description                                   1273 non-null   object
#  7   neighborhood_overview                         737 non-null    object
#  8   picture_url                                   1287 non-null   object
# ...

# %%
data = Cambridge_data.iloc[:,[1,4,5,7]]
data
# Out:
#                                            listing_url           source  \
# 0                    https://www.airbnb.com/rooms/8521  previous scrape
# 1                   https://www.airbnb.com/rooms/11169  previous scrape
# 2                   https://www.airbnb.com/rooms/19581      city scrape
# 3                   https://www.airbnb.com/rooms/27498      city scrape
# 4                   https://www.airbnb.com/rooms/79762      city scrape
# ...                                                ...              ...
# 1282  https://www.airbnb.com/rooms/1313250609203710870      city scrape
# 1283  https://www.airbnb.com/rooms/1313277221998634744      city scrape
# 1284  https://www.airbnb.com/rooms/1313301960513049198      city scrape
# 1285  https://www.airbnb.com/rooms/1314036192803424107      city scrape
# 1286  https://www.airbnb.com/rooms/1316146649117544288      city scrape
#
#                                                   name  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1287 entries, 0 to 1286
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   listing_url            1287 non-null   object
#  1   source                 1287 non-null   object
#  2   name                   1287 non-null   object
#  3   neighborhood_overview  737 non-null    object
# dtypes: object(4)
# memory usage: 40.3+ KB

# %%
data.to_csv("Cambridge.csv")
